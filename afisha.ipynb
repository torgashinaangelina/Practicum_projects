# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b> Ангелина, привет!👋</b>
#
# Меня зовут Алексей Гриб, и я буду ревьюером твоего проекта.
#
# Сразу хочу предложить в дальнейшем общаться на "ты" - надеюсь, так будет комфортнее:) Но если это неудобно, обязательно дай знать, и мы придумаем что-нибудь ещё!
#
# Цель ревью - не искать ошибки в твоём проекте, а помочь тебе сделать твою работу ещё лучше, устранив недочёты и приблизив её к реальным задачам специалиста по работе с данными. Поэтому не расстраивайся, если что-то не получилось с первого раза - это нормально, и это поможет тебе вырасти!
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <br/>
#
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> похвала, рекомендации «со звёздочкой», полезные лайфхаки, которые сделают и без того красивое решение ещё более элегантным.
# </div>
#
# <br/>
#
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> некритичные ошибки или развивающие рекомендации на будущее.
# </div>
#
#
# <br/>
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
# критичные ошибки, которые обязательно нужно исправить.
# </div>
#
#
# Пожалуйста, не удаляй мои комментарии, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
#
# Ты также можешь задавать свои вопросы, реагировать на мои комментарии, делать пометки и пояснения - полная творческая свобода! Но маленькая просьба - пускай они будут отличаться от моих комментариев, это поможет избежать путаницы в нашем общении:)
# Например, вот так:
#
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# *твой текст*
# </div>
#
# Давай посмотрим на твой проект!

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# Привет! Спасибо за проверку моего проекта, исправления и рекомендации! Я постаралась максимально учесть твои пометки и улучшить изначальный вариант.
# </div>

# %% [markdown]
# # Исследование активности пользователей сервисом «Афиша»
#
# ## Цель и задачи
#
# **Цель:** Проведение исследовательского анализа данных активности пользователей сервиса «Афиша» с выявлением инсайтов об изменении пользовательских предпочтений
#
# **Задачи:**
# 1. Загрузить данные и познакомиться с их содержимым.
# 2. Провести предобработку данных.
# 3. Провести исследовательский анализ данных:
#     - изучить данные более детально;
#     - выявить инсайты об изменении пользовательских предпочтений и популярности событий осенью 2024 года;
#     - проверить гипотезы о разнице в поведении пользователей с мобильными и стационарными устройствами.
# 4. Сформулировать выводы по проведённому анализу.
#
#
# ## Данные
#
# Для анализа поступили данные о клиентах банка «Метанпром». Данные состоят из двух датасетов:
#
# - `final_tickets_orders_df.csv` — информация обо всех заказах билетов, совершённых с двух типов устройств — мобильных и стационарных;
# - `final_tickets_events_df.csv` - информация о событиях, включая город и регион события, а также информация о площадке проведения мероприятия.
# - `final_tickets_tenge_df.csv` — информация о курсе тенге к российскому рублю за 2024 год;
#
# ### Описание датасета `final_tickets_orders_df`
#
# - `order_id` — уникальный идентификатор заказа;
# - `user_id` — уникальный идентификатор пользователя;
# - `created_dt_msk` — дата создания заказа (московское время);
# - `created_ts_msk` — дата и время создания заказа (московское время);
# - `event_id` — уникальный идентификатор события;
# - `cinema_circuit` — сеть кинотеатров. Если не применимо, то здесь будет значение 'нет';
# - `age_limit` — возрастное ограничение;
# - `currency_code` — валюта оплаты, например rub для российских рублей;
# - `device_type_canonical` — тип устройства, с которого был оформлен заказ, например mobile для мобильных устройств, desktop для стационарных;
# - `revenue` — выручка от заказа;
# - `service_name` — название билетного оператора;
# - `tickets_count` — количество купленных билетов;
# - `total` — общая сумма заказа.
#
# ### Описание датасета `final_tickets_events_df`
#
# - `event_id` — уникальный идентификатор события;
# - `event_name` — название мероприятия;
# - `event_type_description` — описание типа мероприятия.;
# - `event_type_main` — основной тип мероприятия: театральная постановка, концерт и так далее;
# - `organizers` — организаторы мероприятия;
# - `region_name` — название региона;
# - `city_name` — название города;
# - `venue_id` — уникальный идентификатор площадки;
# - `venue_name` — название площадки;
# - `venue_address` — адрес площадки.
#
# ### Описание датасета `final_tickets_tenge_df`
#
# - `nominal` — номинал (100 тенге);
# - `data` — дата;
# - `curs` — курс тенге к рублю;
# - `cdx` — обозначение валюты (kzt).
#
#
# ## Структура проекта
#
# 1. Загрузка данных и знакомство с ними
#
# 2. Предобработка данных и подготовка их к исследованию.
#
# 3. Исследовательский анализ данных.
#
#     3.1. Анализ распределения заказов по сегментам и их сезонные изменения
#
#     3.2. Осенняя активность пользователей
#
#     3.3. Популярные события и партнёры
#
# 4. Статистический анализ данных
#
# 5. Общий вывод и рекомендации.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Хорошее вступление!
#
# В нём есть всё, что необходимо, чтобы понять суть проекта с первых строк отчёта!

# %% [markdown]
# ## 1. Загрузка данных и знакомство с ними

# %%
# Импортируем библиотеки
import pandas as pd
import numpy as np

# Загружаем библиотеки для визуализации данных
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
import seaborn as sns

# Загружаем библиотеки для статистического анализа
from statsmodels.stats.power import NormalIndPower
from scipy.stats import mannwhitneyu

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Библиотеки импортировали - отлично!

# %%
# Выгружаем данные в переменные purchases и tenge
purchases = pd.read_csv('https://code.s3.yandex.net/datasets/final_tickets_orders_df.csv')
events = pd.read_csv('https://code.s3.yandex.net/datasets/final_tickets_events_df.csv')
tenge = pd.read_csv('https://code.s3.yandex.net/datasets/final_tickets_tenge_df.csv')

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b>
#
# Данные загрузили.
#
# При считывании данных из файла здорово перестраховывать себя от ошибок, связанных, например, с неверным указанием пути к файлу. А иногда бывает, что работаешь с файлом локально, выгружаешь его на сервер, ожидая, что он будет принимать данные, которые лежат на том же сервере, а код падает с ошибкой, потому что путь к файлу не поменялся с локального на серверный.
#
# Для этого, например, можно использовать конструкцию `try-except`: сначала пробуешь локальный путь, при возникновении ошибки используется серверный путь (подробнее можешь почитать тут: https://pythonworld.ru/tipy-dannyx-v-python/isklyucheniya-v-python-konstrukciya-try-except-dlya-obrabotki-isklyuchenij.html).
#
# Но еще лучше использовать библиотеку `os` - её использование позволит тебе проверять существование указанных директорий (что может быть актуально при одновременной работа на локальном и сетевом окружении) и загружать данные из существующей директории, избегая ошибок. Как пример:
#
#     import os
#
#     pth1 = '/folder_1/data.csv'
#     pth2 = '/folder_2/data.csv'
#
#     if os.path.exists(pth1):
#         query_1 = pd.read_csv(pth1)
#     elif os.path.exists(pth2):
#         query_1 = pd.read_csv(pth2)
#     else:
#         print('Something is wrong')
#
# Ещё на этапе считывания данных можно спарсить дату: за это действие отвечает параметр `parse_dates` метода `read_csv()`, в него нужно передать список с названием полей-дат, и в большинстве случаев дата будет корректно преобразована в нужный формат сразу:)
# Также на этапе считывания данных можно задать индекс-столбец - за это действие отвечает параметр `index_col`.

# %%
# Выводим первые строки датафрейма на экран
purchases.head()
# Out:
#    order_id          user_id created_dt_msk       created_ts_msk  event_id  \
# 0   4359165  0002849b70a3ce2     2024-08-20  2024-08-20 16:08:03    169230
# 1   7965605  0005ca5e93f2cf4     2024-07-23  2024-07-23 18:36:24    237325
# 2   7292370  0005ca5e93f2cf4     2024-10-06  2024-10-06 13:56:02    578454
# 3   1139875  000898990054619     2024-07-13  2024-07-13 19:40:48    387271
# 4    972400  000898990054619     2024-10-04  2024-10-04 22:33:15    509453
#
#   cinema_circuit  age_limit currency_code device_type_canonical  revenue  \
# 0            нет         16           rub                mobile  1521.94
# 1            нет          0           rub                mobile   289.45
# 2            нет          0           rub                mobile  1258.57
# 3            нет          0           rub                mobile     8.49
# 4            нет         18           rub                mobile  1390.41
#
#          service_name  tickets_count     total  days_since_prev
# ...

# %%
# Выводим информацию о датафрейме
purchases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290849 entries, 0 to 290848
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   order_id               290849 non-null  int64
#  1   user_id                290849 non-null  object
#  2   created_dt_msk         290849 non-null  object
#  3   created_ts_msk         290849 non-null  object
#  4   event_id               290849 non-null  int64
#  5   cinema_circuit         290849 non-null  object
#  6   age_limit              290849 non-null  int64
#  7   currency_code          290849 non-null  object
#  8   device_type_canonical  290849 non-null  object
#  9   revenue                290849 non-null  float64
#  10  service_name           290849 non-null  object
#  11  tickets_count          290849 non-null  int64
#  12  total                  290849 non-null  float64
#  13  days_since_prev        268909 non-null  float64
# ...

# %%
# Выводим первые строки датафрейма на экран
events.head()
# Out:
#    event_id                            event_name event_type_description  \
# 0      4436  e4f26fba-da77-4c61-928a-6c3e434d793f              спектакль
# 1      5785  5cc08a60-fdea-4186-9bb2-bffc3603fb77              спектакль
# 2      8817  8e379a89-3a10-4811-ba06-ec22ebebe989              спектакль
# 3      8849  682e3129-6a32-4952-9d8a-ef7f60d4c247              спектакль
# 4      8850  d6e99176-c77f-4af0-9222-07c571f6c624              спектакль
#
#   event_type_main organizers           region_name   city_name  city_id  \
# 0           театр      №4893  Североярская область      Озёрск        2
# 1           театр      №1931  Светополянский округ   Глиноград       54
# 2           театр      №4896  Североярская область      Озёрск        2
# 3           театр      №4960    Каменевский регион  Глиногорск      213
# 4           театр      №4770      Лесодальний край  Родниковец       55
#
#    venue_id                               venue_name             venue_address
# ...

# %%
# Выводим информацию о датафрейме
events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22427 entries, 0 to 22426
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   event_id                22427 non-null  int64
#  1   event_name              22427 non-null  object
#  2   event_type_description  22427 non-null  object
#  3   event_type_main         22427 non-null  object
#  4   organizers              22427 non-null  object
#  5   region_name             22427 non-null  object
#  6   city_name               22427 non-null  object
#  7   city_id                 22427 non-null  int64
#  8   venue_id                22427 non-null  int64
#  9   venue_name              22427 non-null  object
#  10  venue_address           22427 non-null  object
# dtypes: int64(3), object(8)
# memory usage: 1.9+ MB

# %%
# Выводим первые строки датафрейма на экран
tenge.head()
# Out:
#          data  nominal     curs  cdx
# 0  2024-01-10      100  19.9391  kzt
# 1  2024-01-11      100  19.7255  kzt
# 2  2024-01-12      100  19.5839  kzt
# 3  2024-01-13      100  19.4501  kzt
# 4  2024-01-14      100  19.4501  kzt

# %%
# Выводим информацию о датафрейме
tenge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   data     357 non-null    object
#  1   nominal  357 non-null    int64
#  2   curs     357 non-null    float64
#  3   cdx      357 non-null    object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 11.3+ KB

# %% [markdown]
# ###### Промежуточный вывод:
# - датасет с покупками состоит из 13 колонок и 290849 строк. в предварительном обзоре пропуски в нем не были обнаружены (кроме столбца days_since_prev , где предполагается наличие пропусков).
# - датасет с событиями состоит из 10 колонок и 22427 строк. в предварительном обзоре пропуски в нем не были обнаружены.
# - датасет с курсом тенге к рублю состоит из 4 колонок и 357 строк. в предварительном обзоре пропуски в нем не были обнаружены.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b> Первичный анализ данных выполнен, отмечено наличие пропусков в `days_since_prev`.

# %% [markdown]
# ## 2. Предобработка данных и подготовка их к исследованию

# %%
# соединяем датафреймы для дальнейшей работы
df_1 = pd.merge(purchases, events, on='event_id', how='left')
df = pd.merge(df_1, tenge, left_on='created_dt_msk',right_on='data', how='left')

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b> Данные соединены корректно.

# %%
# Оцениваем столбцы, где могут быть неявные дубликаты
df.nunique()
# Out:
# order_id                  290849
# user_id                    21940
# created_dt_msk               153
# created_ts_msk            280986
# event_id                   22446
# cinema_circuit                 6
# age_limit                      5
# currency_code                  2
# device_type_canonical          2
# revenue                    42528
# service_name                  36
# tickets_count                 22
# total                      55473
# days_since_prev              149
# event_name                 15248
# event_type_description        20
# event_type_main                7
# organizers                  4293
# region_name                   81
# city_name                    352
# city_id                      353
# venue_id                    3225
# venue_name                  3217
# venue_address               3225
# data                         153
# nominal                        1
# curs                         108
# cdx                            1
# dtype: int64

# %%
# Проверяем уникальные значения в столбцах
for column in ['cinema_circuit', 'age_limit', 'currency_code', 
               'device_type_canonical', 'service_name', 'event_type_description', 'event_type_main']:
    print(f'Уникальные значения в столбце {column}:')
    print(df[column].sort_values().unique())
    print()
# Out:
# Уникальные значения в столбце cinema_circuit:
# ['Другое' 'КиноСити' 'Киномакс' 'Москино' 'ЦентрФильм' 'нет']
#
# Уникальные значения в столбце age_limit:
# [ 0  6 12 16 18]
#
# Уникальные значения в столбце currency_code:
# ['kzt' 'rub']
#
# Уникальные значения в столбце device_type_canonical:
# ['desktop' 'mobile']
#
# Уникальные значения в столбце service_name:
# ['Crazy ticket!' 'Show_ticket' 'Билет по телефону' 'Билеты без проблем'
#  'Билеты в интернете' 'Билеты в руки' 'Быстробилет' 'Быстрый кассир'
#  'Весь в билетах' 'Восьмёрка' 'Вперёд!' 'Выступления.ру'
#  'Городской дом культуры' 'Дом культуры' 'Дырокол' 'За билетом!'
#  'Зе Бест!' 'КарандашРУ' 'Кино билет' 'Край билетов' 'Лимоны'
#  'Лови билет!' 'Лучшие билеты' 'Мир касс' 'Мой билет' 'Облачко'
#  'Прачечная' 'Радио ticket' 'Реестр' 'Росбилет' 'Тебе билет!' 'Телебилет'
#  'Тех билет' 'Цвет и билет' 'Шоу начинается!' 'Яблоко']
#
# Уникальные значения в столбце event_type_description:
# ...

# %%
df['event_type_description'] = df['event_type_description'].replace('спорт', 'спортивное мероприятие')

# Для проверки изменений можно вывести уникальные значения столбца еще раз
print("Уникальные значения в столбце event_type_description после замены:")
print(df['event_type_description'].nunique())
# Out:
# Уникальные значения в столбце event_type_description после замены:
# 19

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b> Молодец, что обработала неявный дубликат. Категориальные признаки исследованы.

# %%
# Создаём контейнер графика matplotlib и задаём его размер
plt.figure(figsize=(7, 3))

# Строим гистограмму с помощью pandas через plot(kind='hist')
df['revenue'][df['currency_code']=='rub'].plot(
                kind='hist', # Тип графика - гистограмма
                bins=10, # Устанавливаем количество корзин
                alpha=0.75,
                edgecolor='black',
                rot=0, # Градус вращения подписи по оси Х
)

# Настраиваем оформление графика
plt.title('Распределение значений выручки с заказа (в руб.)')
plt.xlabel('Выручка (руб.)')
plt.ylabel('Частота')
# Добавляем сетку графика
plt.grid()

# Выводим график
plt.show()

# %%
# Вычисляем 99-й процентиль
percentile_99 = df['revenue'].quantile(0.99)

# Фильтруем Series, оставляя значения, которые больше или равны 99-му процентилю
filtered_series = df['revenue'][(df['revenue'] <= percentile_99) & (df['currency_code']=='rub')]

# Создаём контейнер графика matplotlib и задаём его размер
plt.figure(figsize=(7, 2))

# Строим диаграмму размаха значений в столбце
filtered_series.plot.box(vert=False)

# Добавляем заголовок и метки оси
plt.title('Распределение значений выручки с заказа (в руб.)')
plt.xlabel('Выручка (руб.)')

# Выводим график
plt.show()

# %%
# Создаём контейнер графика matplotlib и задаём его размер
plt.figure(figsize=(7, 3))

# Строим гистограмму с помощью pandas через plot(kind='hist')
df['revenue'][df['currency_code']=='kzt'].plot(
                kind='hist', # Тип графика - гистограмма
                bins=10, # Устанавливаем количество корзин 
                alpha=0.75,
                edgecolor='black',
                rot=0, # Градус вращения подписи по оси Х
)

# Настраиваем оформление графика
plt.title('Распределение значений выручки с заказа (в тенге)')
plt.xlabel('Выручка (тенге)')
plt.ylabel('Частота')
# Добавляем сетку графика
plt.grid()

# Выводим график
plt.show()

# %%
# Создаём контейнер графика matplotlib и задаём его размер
plt.figure(figsize=(7, 3))

# Строим гистограмму с помощью pandas через plot(kind='hist')
df['tickets_count'].plot(
                kind='hist', # Тип графика - гистограмма
                bins=10, # Устанавливаем количество корзин 
                alpha=0.75,
                edgecolor='black',
                rot=0, # Градус вращения подписи по оси Х
)

# Настраиваем оформление графика
plt.title('Распределение количества билетов в заказе')
plt.xlabel('Количество билетов в заказе')
plt.ylabel('Частота')
# Добавляем сетку графика
plt.grid()

# Выводим график
plt.show()

# %%
# Создаём контейнер графика matplotlib и задаём его размер
plt.figure(figsize=(7, 3))

# Строим гистограмму с помощью pandas через plot(kind='hist')
df['total'][df['currency_code']=='rub'].plot(
                kind='hist', # Тип графика - гистограмма
                bins=10, # Устанавливаем количество корзин
                alpha=0.75,
                edgecolor='black',
                rot=0, # Градус вращения подписи по оси Х
)

# Настраиваем оформление графика
plt.title('Распределение стоимости заказа (в руб.)')
plt.xlabel('Стоимость заказа (руб.)')
plt.ylabel('Частота')
# Добавляем сетку графика
plt.grid()

# Выводим график
plt.show()

# %%
# Вычисляем 99-й процентиль
percentile_99 = df['total'].quantile(0.99)

# Фильтруем Series, оставляя значения, которые больше или равны 99-му процентилю
filtered_series = df['total'][(df['total'] <= percentile_99) & (df['currency_code']=='rub')]

# Создаём контейнер графика matplotlib и задаём его размер
plt.figure(figsize=(7, 2))

# Строим диаграмму размаха значений в столбце
filtered_series.plot.box(vert=False)

# Добавляем заголовок и метки оси
plt.title('Распределение стоимости заказа (в руб.)')
plt.xlabel('Стоимость заказа (руб.)')

# Выводим график
plt.show()

# %% [markdown]
# #### Фильтрация

# %%
# считаем изначальное количество строк
initial_num = df.shape[0]

# разделяем фрейм по валютам, считаем строки в фрейме с тенге
df_kzt = df[df['currency_code']=='kzt']
kzt_num = df_kzt.shape[0]
df_rub = df[df['currency_code']=='rub']

# фильтруем фрейм с рублями по 99-процентилю
percentile_99 = df_rub['revenue'].quantile(0.99)
filtered_series = df_rub[(df_rub['revenue'] <= percentile_99)]
filt_num = filtered_series.shape[0]

# соединяем фреймы в один
df = pd.concat([df_kzt, filtered_series], axis=0)
final_num = df.shape[0]
print(f'Количество строк до фильтрации {initial_num}.')
print(f'Количество строк в фрейме с тенге {kzt_num}.')
print(f'Количество строк в фрейме с рублями и с фильтрацией по 99-процентилю {filt_num}.')
print(f'Количество строк после фильтрации {final_num} равно сумме 2 и 3 фрейма {kzt_num+filt_num}.')
# Out:
# Количество строк до фильтрации 290849.
# Количество строк в фрейме с тенге 5069.
# Количество строк в фрейме с рублями и с фильтрацией по 99-процентилю 282922.
# Количество строк после фильтрации 287991 равно сумме 2 и 3 фрейма 287991.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b> Численные признаки исследованы.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b>
#
# 1. Выбросы стоит фильтровать там, где это необходимо - в выручке `kzt` и числе билетов явных выбросов нет, поэтому там фильтрацию делать не нужно.
# 2. Выбросы фильтруются только на уровне `filtered_series`, но не на уровне основной таблицы `df` - нужно сохранить результат фильтрации по выручке в рублях в основной таблице.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# удалила дополнительные исследования там, где они не нужны, добавила фильтрацию в новом пункте
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ###### Промежуточный вывод:
# - были проверены категориальные и количественные данные на наличие ошибок или аномалий.
# - категориальные данные соответсвуют норме.
# - в количественных данных было найдено несколько аномалий. рассматривались столбцы revenue, total, tickets_count.
# - revenue: распределение данных, представленных в рублях, ненормальное и содержит много выбросов. при его фильтрации по 99-ому процентилю видим, что размах равен примерно 2000, присутсвует большое количество выбросов вплоть до 4000. распределение данных, представленных в тенге, ассимитричное и содержит много выбросов. при его фильтрации по 99-ому процентилю видим, что размах равен 4000 без выбросов.
# - tickets_count: распределение данных ненормальное и содержит много выбросов. при его фильтрации по 99-ому процентилю видим, что размах равен 4, также есть выбросы (5 и 6), которые часто встречаются.
# - total: распределение данных, представленных в рублях, ненормальное и содержит много выбросов. при его фильтрации по 99-ому процентилю видим, что размах равен примерно 20000, присутсвует большое количество выбросов вплоть до 60000. распределение данных, представленных в тенге, ассимитричное и содержит много выбросов. при его фильтрации по 99-ому процентилю видим, что размах равен около 60000 без выбросов.
# - также в поле total наблюдаем 6109 строк, где значение равно 0. это может означать, что по каким-то причинам покупка была бесплатной, что является странным наблюдением.
# - датасет в основном состоит из категориальных данных.
# - я выбрала на проверку столбцы, в которых могли бы содержаться неявные дубликаты.
# - в ходе проверки были обнаружены 2 категории "спортивные мероприятия" и "спорт", которые я решила объединить в одну категорию "спортивные мероприятия".
# - датасет в основном содержит категориальные данные, в которых не встречаются неявные дубликаты.
# - в одном столбце есть количественные данные. их распределение нормальное с небольшим выбросом. однако, учитывая специфику столбца (курс валют), мы не можем назвать эти выбросы аномалией и исключить их из анализа.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b> Молодец, что не забываешь про промежуточные выводы.

# %% [markdown]
# #### Дубликаты

# %%
initial_row_count = df.shape[0] #количество строк до всех дубликатов
df_sorted = df.sort_values(by=df.columns.tolist())
quantity_of_dup=df_sorted.duplicated(keep=False).sum()
print(f'Количество дубликатов:{quantity_of_dup}')
# Out:
# Количество дубликатов:0

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b> Явные дубликаты отсутствуют.

# %%
df.columns
# Out:
# Index(['order_id', 'user_id', 'created_dt_msk', 'created_ts_msk', 'event_id',
#        'cinema_circuit', 'age_limit', 'currency_code', 'device_type_canonical',
#        'revenue', 'service_name', 'tickets_count', 'total', 'days_since_prev',
#        'event_name', 'event_type_description', 'event_type_main', 'organizers',
#        'region_name', 'city_name', 'city_id', 'venue_id', 'venue_name',
#        'venue_address', 'data', 'nominal', 'curs', 'cdx'],
#       dtype='object')

# %%
df_sorted = df.sort_values(by=df.columns.tolist())
quantity_of_dup=df_sorted.duplicated(keep=False, subset=['user_id', 'created_dt_msk', 'created_ts_msk', 'event_id',
       'cinema_circuit', 'age_limit', 'currency_code', 'device_type_canonical',
       'revenue', 'service_name', 'tickets_count', 'total', 'days_since_prev',
       'event_name', 'event_type_description', 'event_type_main', 'organizers',
       'region_name', 'city_name', 'city_id', 'venue_id', 'venue_name',
       'venue_address', 'data', 'nominal', 'curs', 'cdx']).sum()
print(f'Количество дубликатов:{quantity_of_dup}')
# Out:
# Количество дубликатов:58

# %%
df =df_sorted.drop_duplicates(keep='first', subset=['user_id', 'created_dt_msk', 'created_ts_msk', 'event_id',
       'cinema_circuit', 'age_limit', 'currency_code', 'device_type_canonical',
       'revenue', 'service_name', 'tickets_count', 'total', 'days_since_prev',
       'event_name', 'event_type_description', 'event_type_main', 'organizers',
       'region_name', 'city_name', 'city_id', 'venue_id', 'venue_name',
       'venue_address', 'data', 'nominal', 'curs', 'cdx'])

# %%
df_sorted = df.sort_values(by=df.columns.tolist())
quantity_of_dup=df_sorted.duplicated(keep=False, subset=['user_id', 'event_id', 'created_ts_msk', 
                                                               'device_type_canonical', 'total', 'tickets_count']).sum()
print(f'Количество дубликатов:{quantity_of_dup}')
# Out:
# Количество дубликатов:18

# %%
df =df_sorted.drop_duplicates(keep='first', subset=['user_id', 'event_id', 'created_ts_msk', 
                                                               'device_type_canonical', 'total', 'tickets_count'])
final_row_count = df.shape[0]

print(f"Количество строк до удаления пропусков и дубликатов: {initial_row_count}")
print(f"Количество строк после удаления пропусков и дубликатов: {final_row_count}")
print(f"Количество удаленных строк: {initial_row_count-final_row_count}")
print(f"Процент удаленных строк: {round(((initial_row_count-final_row_count)/initial_row_count)*100, 2)}%")
# Out:
# Количество строк до удаления пропусков и дубликатов: 287991
# Количество строк после удаления пропусков и дубликатов: 287952
# Количество удаленных строк: 39
# Процент удаленных строк: 0.01%

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b> Молодец, что оцениваешь потери данных при фильтрации.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# исправлено
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Неявные дубликаты нужно проверить по всем признакам, кроме `order_id`.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ###### Промежуточный вывод:
# - все 3 датасета были проверены на полные дубликаты.
# - датасет с покупками также был проверен на неявные дубликаты по нескольким полям: айди покупателя, айди мероприятия, время покупки с точностью до секунд, тип устройства, сумма покупки и количество билетов. поля были выбраны из соображения о том, что один и тот же пользователь не может совершать одинаковое действие в одну секунду.
# - в ходе предыдущего пункта было обнаружено и удалено 39 дубликатов, что составило 0,01% от всего датасета.
#
# #### Преобразование типов данных

# %%
df['created_dt_msk']=pd.to_datetime(df['created_dt_msk'])
df['created_ts_msk']=pd.to_datetime(df['created_ts_msk'])
df['data']=pd.to_datetime(df['data'])
# Out:
# /tmp/ipykernel_96/1204576889.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['created_dt_msk']=pd.to_datetime(df['created_dt_msk'])
# /tmp/ipykernel_96/1204576889.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['created_ts_msk']=pd.to_datetime(df['created_ts_msk'])
# /tmp/ipykernel_96/1204576889.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %% [markdown]
# ###### Промежуточный вывод:
# - была проведена нормализация данных
# - столбцы, содержащие данные даты, были переведы в соответствующий вид
#
# #### Создание дополнительных столбцов

# %%
# создаем столбец, где переводим выручку из тенге в рубли
def calculate_revenue_rub(row):
    """
    Вычисляет выручку в рублях на основе данных строки.
    """
    if row['currency_code'] == 'rub':
        return row['revenue']
    elif row['currency_code'] == 'kzt':
        return (row['revenue'] / row['nominal']) * row['curs']
    else:
        return None  # Или другое значение по умолчанию, если встречаются другие валюты

# Применяем функцию к каждой строке DataFrame для создания нового столбца
df['revenue_rub'] = df.apply(calculate_revenue_rub, axis=1)
# создаем столбец, содержащий информацию о выручке с 1 билета в заказе
df['one_ticket_revenue_rub']=df['revenue']/df['tickets_count']
# создаем столбец с номером месяца
df['month']=pd.DatetimeIndex(df['created_dt_msk']).month
# создаем функцию, которая на основе номера месяца определяет время года
def season(df_column):
    if df_column in [12, 1, 2]:
        return 'зима'
    elif df_column in [3, 4, 5]:
        return 'весна'
    elif df_column in [6, 7, 8]:
        return 'лето'
    elif df_column in [9, 10, 11]:
        return 'осень'
    else:
        return 'Некорректный месяц'
# создаем столбец, содержащий название времени года    
df['season'] = df['month'].apply(season)
# Out:
# /tmp/ipykernel_96/290849937.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['revenue_rub'] = df.apply(calculate_revenue_rub, axis=1)
# /tmp/ipykernel_96/290849937.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['one_ticket_revenue_rub']=df['revenue']/df['tickets_count']
# /tmp/ipykernel_96/290849937.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df.head()
# Out:
#         order_id          user_id created_dt_msk      created_ts_msk  \
# 83261          1  3ebd0c4b59f6bdd     2024-08-08 2024-08-08 15:01:11
# 43668         30  1a66f181a803c75     2024-09-05 2024-09-05 19:44:21
# 43665         59  1a66f181a803c75     2024-07-25 2024-07-25 10:09:41
# 146705        88  7997823870f2b1b     2024-09-26 2024-09-26 16:03:44
# 48374        117  1c5bac640c12e86     2024-09-15 2024-09-15 14:18:07
#
#         event_id cinema_circuit  age_limit currency_code  \
# 83261     555432            нет         16           rub
# 43668     149337            нет         16           rub
# 43665     269938            нет         12           rub
# 146705    561834            нет         18           rub
# 48374     568660            нет          0           rub
#
#        device_type_canonical  revenue  ...  \
# 83261                 mobile   568.43  ...
# 43668                 mobile   575.08  ...
# 43665                desktop   402.51  ...
# ...

# %% [markdown]
# ###### Промежуточный вывод:
# - были созданы 4 новых столбца
# - revenue_rub — выручка с заказов в единой валюте — российском рубле
# - one_ticket_revenue_rub — выручка с продажи одного билета на мероприятие
# - month — месяц оформления заказа
# - season — столбец с информацией о сезонности, включая такие категории, как: 'лето', 'осень', 'зима', 'весна'

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b> Типы данных скорректированы, новые признаки добавлены в выборку.

# %% [markdown]
# ## 3. Исследовательский анализ данных
# ### 3.1. Анализ распределения заказов по сегментам и их сезонные изменения

# %%
# Рассмотрим распределение количества заказов по месяцам
tick_count = df.groupby('month')['order_id'].count().reset_index()
tick_count
# Out:
#    month  order_id
# 0      6     34372
# 1      7     40408
# 2      8     44570
# 3      9     69331
# 4     10     99271

# %%
ax = tick_count.plot(kind='bar', 
                    title='Cоотношение заказов по месяцам', 
                    legend=False, 
                    xlabel='Месяц', 
                    ylabel='Количество заказ',
                    figsize=(12, 8), 
                 rot=0)
ax.set_xticklabels(['июнь', 'июль', 'август', 'сентябрь', 'октябрь'])
plt.show()

# %% [markdown]
# ###### Промежуточный вывод:
# - с каждым месяцем наблюдается увеличение количества заказов, прослеживается восходящий тренд
# - пик наблюдается в октябре

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍</b> Исследована динамика заказов по месяцам.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> По результатам нужно сделать выводы.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# исправлено
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
# Группируем: считаем количество заказов по дате, сезону и типу мероприятия
order_counts = df.groupby(['season', 'event_type_main'])['order_id'].count().reset_index()
order_counts.rename(columns={'order_id': 'order_count'}, inplace=True)

# %%
# 1. Подсчёт общего количества заказов по сезону (для расчёта доли)
season_totals = order_counts.groupby('season')['order_count'].sum().reset_index()
season_totals.rename(columns={'order_count': 'total_orders'}, inplace=True)

# 2. Присоединяем общие суммы к order_counts
order_counts = order_counts.merge(season_totals, on='season')
order_counts['share'] = order_counts['order_count'] / order_counts['total_orders'] * 100

# 3. Группируем данные для построения диаграммы
pivot_df = order_counts.pivot_table(
    index='event_type_main',
    columns='season',
    values='share'
).reset_index()

# 4. Построение группированной столбчатой диаграммы
plt.figure(figsize=(12, 6))

# Переход к long-формату для seaborn
melted = order_counts[['event_type_main', 'season', 'share']]
sns.barplot(
    data=melted,
    x='event_type_main',
    y='share',
    hue='season',
    palette='Set2'
)

# 5. Добавление % изменений над столбцами
for i, event in enumerate(pivot_df['event_type_main']):
    row = pivot_df[pivot_df['event_type_main'] == event]
    if row.shape[1] >= 3:
        values = row.iloc[0]
        if 'лето' in row.columns and 'осень' in row.columns:
            summer = values['лето']
            autumn = values['осень']
            delta = (autumn - summer) / summer * 100 if summer != 0 else 0
            label = f"{delta:+.1f}%"
            max_val = max(summer, autumn)
            plt.text(i, max_val + 1, label, ha='center', fontweight='bold')

# Оформление
plt.title('Доля заказов по типам мероприятий и сезону (% от общего числа мероприятий в сезоне)')
plt.ylabel('Доля (%)')
plt.xlabel('Тип мероприятия')
plt.xticks(rotation=45)
plt.legend(title='Сезон')
plt.tight_layout()
plt.show()

# %% [markdown]
# ###### Промежуточный вывод:
# - из 7 типов мероприятий только у 3 вырастает доля заказов (спорт, театр и елки). последний тип можно объяснить сезонностью и приближением новогднего периода
# - доля заказов в категории спорта и елок вырастает практически в 3,5 раза, а доля заказов в театр растет не так быстро (+26,6%)
# - остальные категории падают на 12,8-28,7%.
# - сложно оценить причины такого падения

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Гистограмма плотности не подходит для анализа распределения дискретных величин. Доли можно посчитать с помощью `value_counts(normalize=True)` или с помощью группировки.
#
# Также разделение визуализации на каждый отдельный график на каждое отдельное значение признака может быть неэффективным, если уникальных значений признака будет очень много. Удобнее будет по оси Х отложить значение признака, по оси Y значения долей - так мы сможем удобнее сравнивать различие долей между сезонами для каждого значения признака.
#
# Тут и далее.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# исправлено
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
order_counts = df.groupby(['season', 'device_type_canonical'])['order_id'].count().reset_index()
order_counts.rename(columns={'order_id': 'order_count'}, inplace=True)

# %%
# 1. Подсчёт общего количества заказов по сезону
season_totals = order_counts.groupby('season')['order_count'].sum().reset_index()
season_totals.rename(columns={'order_count': 'total_orders'}, inplace=True)

# 2. Присоединяем общие суммы к order_counts
order_counts = order_counts.merge(season_totals, on='season')
order_counts['share'] = order_counts['order_count'] / order_counts['total_orders'] * 100

# 3. Группируем данные для аннотаций
pivot_df = order_counts.pivot_table(
    index='device_type_canonical',
    columns='season',
    values='share'
).reset_index()

# 4. Визуализация
plt.figure(figsize=(10, 6))

# Переводим в long-формат для seaborn
melted = order_counts[['device_type_canonical', 'season', 'share']]
sns.barplot(
    data=melted,
    x='device_type_canonical',
    y='share',
    hue='season',
    palette='Set2'
)

# 5. Добавление аннотаций над парами столбцов
for i, device in enumerate(pivot_df['device_type_canonical']):
    row = pivot_df[pivot_df['device_type_canonical'] == device]
    if row.shape[1] >= 3:
        values = row.iloc[0]
        seasons = list(pivot_df.columns[1:])  # пропускаем первый столбец (device)
        if len(seasons) == 2:
            s1, s2 = seasons
            v1 = values[s1]
            v2 = values[s2]
            delta = (v2 - v1) / v1 * 100 if v1 != 0 else 0
            label = f"{delta:+.1f}%"
            max_val = max(v1, v2)
            plt.text(i, max_val + 1, label, ha='center', fontweight='bold')

# Оформление
plt.title('Доля заказов по типу устройства в сезонах (% от общего числа заказов в сезоне)')
plt.ylabel('Доля (%)')
plt.xlabel('Тип устройства')
plt.xticks(rotation=45)
plt.legend(title='Сезон')
plt.tight_layout()
plt.show()

# %% [markdown]
# ###### Промежуточный вывод:
# - доля заказов со стационарных устройств растет на 5%
# - доля заказов с мобильных устройств падает на 1,2%
# - на диаграмме можно увидеть, что это незначительные и почти незаметные изменения, которые не могут быть статистически значимыми

# %%
#import pandas as pd
#import matplotlib.pyplot as plt
#import seaborn as sns
# Группировка и расчет количества заказов
order_counts = df.groupby(['season', 'age_limit'])['order_id'].count().reset_index()
order_counts.rename(columns={'order_id': 'order_count'}, inplace=True)

# Доля заказов в рамках сезона
order_counts['share'] = order_counts.groupby('season')['order_count'].transform(lambda x: x / x.sum() * 100)

# Пивот для сравнения сезонов
pivot_df = order_counts.pivot(index='age_limit', columns='season', values='share').fillna(0)

# Построение графика
plt.figure(figsize=(14, 6))
sns.barplot(data=order_counts, x='age_limit', y='share', hue='season', palette='Set2')

# Добавление % изменений между сезонами (лето и осень)
if 'лето' in pivot_df.columns and 'осень' in pivot_df.columns:
    for i, age in enumerate(pivot_df.index):
        summer = pivot_df.loc[age, 'лето']
        autumn = pivot_df.loc[age, 'осень']
        if summer != 0:
            delta = (autumn - summer) / summer * 100
            delta_str = f'{delta:+.1f}%'
        else:
            delta_str = '–'
        y_max = max(summer, autumn)
        plt.text(i, y_max + 1.5, delta_str, ha='center', fontweight='bold', fontsize=9)

# Оформление
plt.title('Доля заказов по возрастному ограничению (лето vs осень)', fontsize=14)
plt.xlabel('Возрастное ограничение')
plt.ylabel('Доля заказов, %')
plt.xticks(rotation=45)
plt.ylim(0, order_counts['share'].max() + 15)
plt.legend(title='Сезон')
plt.grid(axis='y', linestyle='--', alpha=0.5)

# Это помогает избежать обрезки подписей
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %% [markdown]
# ###### Промежуточный вывод:
# - можно увидеть падение доли заказов на мероприятия со следующим возрастным ограничением: 6+ (2,9%), 16+ (7,3%) и 18+ (30,6%)
# - эти падения можно связать с сезонностью (дети возвращаются в школу, взрослые выходят на работу после отпуска)
# - доли растут в категориях 0+ (31,7%) и 12+ (7,4%)
# - это также объясняется сезонностью, вместо прогулок на свежем воздухе дети в детских садах и школах начинают чаще посещать культурные мероприятия

# %%
# 1. Выручка с одного билета
df['revenue_per_ticket'] = df['revenue_rub'] / df['tickets_count']

# 2. Средняя выручка по мероприятию и сезону
avg_rev = df.groupby(['event_type_main', 'season'])['revenue_per_ticket'].mean().reset_index()

# 3. Относительное изменение: формируем pivot и считаем %
pivot = avg_rev.pivot(index='event_type_main', columns='season', values='revenue_per_ticket')
pivot['change_%'] = ((pivot['осень'] - pivot['лето']) / pivot['лето']) * 100
pivot = pivot.reset_index()

# 4. Объединяем pivot с оригинальными средними значениями, чтобы отобразить всё на одном графике
avg_rev_with_change = avg_rev.merge(pivot[['event_type_main', 'change_%']], on='event_type_main')

# 5. Построение графика
plt.figure(figsize=(12, 6))
ax = sns.barplot(
    data=avg_rev_with_change,
    x='event_type_main',
    y='revenue_per_ticket',
    hue='season',
    palette='Set2'
)

# Добавление подписей с % изменений (только один раз на категорию)
for i, event in enumerate(pivot['event_type_main']):
    change = pivot.loc[pivot['event_type_main'] == event, 'change_%'].values[0]
    ypos = max(
        avg_rev_with_change[(avg_rev_with_change['event_type_main'] == event)]['revenue_per_ticket']
    )
    ax.text(i, ypos + 1, f'{change:+.1f}%', ha='center', va='bottom', fontsize=10, fontweight='bold', color='black')

# Оформление
plt.title('Средняя выручка с билета по типу мероприятия (Лето vs Осень) + % изменения')
plt.xlabel('Тип мероприятия')
plt.ylabel('Выручка за билет (руб)')
plt.xticks(rotation=45)
plt.legend(title='Сезон')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_96/255762350.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['revenue_per_ticket'] = df['revenue_rub'] / df['tickets_count']

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> А вот тут очень классный способ визуализации!

# %% [markdown]
# ###### Промежуточный вывод:
# - однако из 7 типов мероприятий увеличение чека прослеживается только в двух (выставки на 4,8% и стендап на 5,8%)
# - падение среднего чека варьируется от 1,6% до 17,8%
# - эти события могут указывать на то, что люди осенью начинают чаще куда-либо ходить, но выбирают мероприятия более низкой стоимостью

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Исследована сезонная динамика по категориям, а также изменения выручки. При необходимости после устранения замечания по формату визуализации не забудь скорректировать выводы.

# %% [markdown]
# ### 3.2. Осенняя активность пользователей

# %%
# фильтруем датафрейм по осенним месяцам
df_fall = df[df['season']=='осень']

# %%
# Сначала агрегируем по дате
daily_stats = df_fall.groupby('created_dt_msk').agg(
    orders_count=('order_id', 'count'),
    dau=('user_id', 'nunique'),
    total_revenue=('revenue_rub', 'sum'),
    total_tickets=('tickets_count', 'sum')
).reset_index()

# Теперь добавим производные метрики
daily_stats['orders_per_user'] = daily_stats['orders_count'] / daily_stats['dau']
daily_stats['revenue_per_ticket'] = daily_stats['total_revenue'] / daily_stats['total_tickets']

# %%
daily_stats = daily_stats.drop(columns=['total_revenue', 'total_tickets'])
daily_stats.head()
# Out:
#   created_dt_msk  orders_count  dau  orders_per_user  revenue_per_ticket
# 0     2024-09-01          1327  564         2.352837          195.321654
# 1     2024-09-02          1380  574         2.404181          189.940163
# 2     2024-09-03          5111  778         6.569409           75.291326
# 3     2024-09-04          1773  685         2.588321          178.486258
# 4     2024-09-05          1944  739         2.630582          189.760908

# %%
fig, axs = plt.subplots(4, 1, figsize=(14, 12), sharex=True)

# Первый график — количество заказов
axs[0].plot(daily_stats['created_dt_msk'], daily_stats['orders_count'], color='steelblue')
axs[0].set_title('Количество заказов по дням')
axs[0].set_ylabel('Заказы')
axs[0].grid(True)

# Второй график — DAU
axs[1].plot(daily_stats['created_dt_msk'], daily_stats['dau'], color='darkorange')
axs[1].set_title('Количество уникальных пользователей (DAU)')
axs[1].set_ylabel('Пользователи')
axs[1].grid(True)

# Третий график — заказов на пользователя
axs[2].plot(daily_stats['created_dt_msk'], daily_stats['orders_per_user'], color='seagreen')
axs[2].set_title('Среднее количество заказов на одного пользователя')
axs[2].set_ylabel('Заказы/Пользователь')
axs[2].grid(True)

# Четвёртый график — средняя стоимость билета
axs[3].plot(daily_stats['created_dt_msk'], daily_stats['revenue_per_ticket'], color='crimson')
axs[3].set_title('Средняя стоимость билета (руб.)')
axs[3].set_ylabel('₽ за билет')
axs[3].set_xlabel('Дата')
axs[3].grid(True)

# Общая настройка
plt.tight_layout()
plt.xticks(rotation=45)
plt.show()

# %%
daily_stats['created_dt_msk'] = pd.to_datetime(daily_stats['created_dt_msk'])
daily_stats['day_of_week'] = daily_stats['created_dt_msk'].dt.day_name()

# %%
weekly_summary = daily_stats.groupby('day_of_week').agg(
    avg_orders=('orders_count', 'mean'),
    avg_dau=('dau', 'mean'),
    avg_orders_per_user=('orders_per_user', 'mean'),
    avg_revenue_per_ticket=('revenue_per_ticket', 'mean')
).reset_index()

# %%
days_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
weekly_summary['day_of_week'] = pd.Categorical(weekly_summary['day_of_week'], categories=days_order, ordered=True)
weekly_summary = weekly_summary.sort_values('day_of_week')

# %%
# Цвета для будней и выходных
weekday_color = '#1f77b4'     # Синий
weekend_color = '#ff7f0e'     # Оранжевый

# Определим, какие дни — выходные
weekend_days = ['Saturday', 'Sunday']

# Функция для покраски столбцов
def get_bar_colors(day_list):
    return [weekend_color if day in weekend_days else weekday_color for day in day_list]

# Создаём графики
fig, axs = plt.subplots(4, 1, figsize=(14, 12), sharex=True)

# 1. Среднее количество заказов
axs[0].bar(
    weekly_summary['day_of_week'],
    weekly_summary['avg_orders'],
    color=get_bar_colors(weekly_summary['day_of_week'])
)
axs[0].set_title('Среднее количество заказов по дням недели')
axs[0].set_ylabel('Заказы')
axs[0].grid(True)

# 2. DAU
axs[1].bar(
    weekly_summary['day_of_week'],
    weekly_summary['avg_dau'],
    color=get_bar_colors(weekly_summary['day_of_week'])
)
axs[1].set_title('Среднее число уникальных пользователей (DAU)')
axs[1].set_ylabel('Пользователи')
axs[1].grid(True)

# 3. Среднее число заказов на пользователя
axs[2].bar(
    weekly_summary['day_of_week'],
    weekly_summary['avg_orders_per_user'],
    color=get_bar_colors(weekly_summary['day_of_week'])
)
axs[2].set_title('Среднее число заказов на пользователя')
axs[2].set_ylabel('Заказы/Пользователь')
axs[2].grid(True)

# 4. Средняя стоимость билета
axs[3].bar(
    weekly_summary['day_of_week'],
    weekly_summary['avg_revenue_per_ticket'],
    color=get_bar_colors(weekly_summary['day_of_week'])
)
axs[3].set_title('Средняя стоимость билета')
axs[3].set_ylabel('₽ за билет')
axs[3].set_xlabel('День недели')
axs[3].grid(True)

# Добавим легенду
legend_elements = [
    Patch(facecolor=weekday_color, label='Будни'),
    Patch(facecolor=weekend_color, label='Выходные')
]
axs[0].legend(handles=legend_elements, loc='upper right')

plt.tight_layout()
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ###### Промежуточный вывод:
# - видим итересную ситуацию: с увеличением количества заказов, количества уникальных пользователей и, соответсвенно, с увеличением среднего числа заказов на пользователям, происходит уменьшение среднего чека.
# - если брать недельную аналитику, то то же самое наблюдаем с увеличениеями и падениями а также: вторник самый популярный день для заказов, но в количестве уникальных пользователей вторник уступает более популрной пятнице.
# - вторник - день с наименьшим средним чеком.
# - говоря о выходных, по субботам мы имеем больше заказов, больше уникальных пользователей и выше среднего количества заказов на пользователя.
# - с средним чеком наоборот: по воскресеньям средний чек выше и в рамках выходных, и в целом на всей неделе.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Осенняя динамика, а также недельны кобебания исследованы корректно.

# %% [markdown]
# ### 3.3. Популярные события и партнёры

# %%
region_stats = df_fall.groupby('region_name').agg(
    unique_events=('event_id', 'nunique'),
    total_orders=('order_id', 'count')
).reset_index()

# Добавим доли
region_stats['events_share'] = region_stats['unique_events'] / region_stats['unique_events'].sum()
region_stats['orders_share'] = region_stats['total_orders'] / region_stats['total_orders'].sum()

# Сортировка по разнообразию
region_stats_sorted = region_stats.sort_values('unique_events', ascending=False)

# %%
# 1. Barplot: Топ-10 регионов по уникальным событиям
top10 = region_stats_sorted.head(10)

plt.figure(figsize=(12, 6))
ax = sns.barplot(
    data=top10, 
    x='unique_events', 
    y='region_name', 
    palette='Blues_d'
)

plt.title('Топ-10 регионов по числу уникальных событий (осень 2024)')
plt.xlabel('Количество уникальных событий')
plt.ylabel('Регион')

# Формируем строки легенды: Регион — XX%
legend_labels = [
    f"{row.region_name} — {row.events_share:.1%}" for _, row in top10.iterrows()
]

# Добавляем легенду (в одну колонку, можно настроить)
ax.legend(
    legend_labels, 
    title='Доли уникальных событий',
    bbox_to_anchor=(1.05, 1),  # расположим справа от графика
    loc='upper left',
    borderaxespad=0.
)

plt.tight_layout()
plt.show()

# %%
# 1. Barplot: Топ-10 регионов по уникальным событиям
top10 = region_stats.sort_values('total_orders', ascending=False).head(10)

plt.figure(figsize=(12, 6))
ax = sns.barplot(
    data=top10, 
    x='total_orders', 
    y='region_name', 
    palette='Blues_d'
)

plt.title('Топ-10 регионов по числу заказов (осень 2024)')
plt.xlabel('Количество заказов')
plt.ylabel('Регион')

# 2. Pie chart: Доли заказов по регионам (топ-10 по заказам + прочее)
top_orders = region_stats.sort_values('total_orders', ascending=False).head(10)
others_orders = region_stats['total_orders'].sum() - top_orders['total_orders'].sum()

labels = list(top_orders['region_name']) + ['Прочее']
sizes = list(top_orders['total_orders']) + [others_orders]

plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('Set3'))
plt.title('Доли заказов по регионам (осень 2024)')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
partner_stats = df_fall.groupby('service_name').agg(
    unique_events=('event_id', 'nunique'),
    total_orders=('order_id', 'count'),
    total_revenue=('revenue_rub', 'sum')
).reset_index()
partner_stats['total_revenue']=partner_stats['total_revenue'].round()
# Доля каждого партнёра
partner_stats['revenue_share'] = partner_stats['total_revenue'] / partner_stats['total_revenue'].sum()
partner_stats['revenue_share']=partner_stats['revenue_share'].round(6)
partner_stats['orders_share'] = partner_stats['total_orders'] / partner_stats['total_orders'].sum()
partner_stats['events_share'] = partner_stats['unique_events'] / partner_stats['unique_events'].sum()
# Сортировка по активности
partner_stats_sorted = partner_stats.sort_values('total_orders', ascending=False)

# %%
partner_stats_sorted = partner_stats.sort_values(['unique_events', 'total_orders', 'total_revenue'], ascending=False)
partner_stats_sorted
# Out:
#               service_name  unique_events  total_orders  total_revenue  \
# 21             Лови билет!           3616         25792     10376793.0
# 3       Билеты без проблем           2847         32382     12115965.0
# 5            Билеты в руки           2471         25732      7613325.0
# 25                 Облачко           1409         15478     10611052.0
# 22           Лучшие билеты           1397         12445      1676010.0
# 24               Мой билет           1006         19419     10850808.0
# 30             Тебе билет!            859          3749      2137900.0
# 26               Прачечная            728          5798      2548310.0
# 8           Весь в билетах            599          9405      9324686.0
# 34                  Яблоко            537          3473      2763332.0
# 12  Городской дом культуры            289          1738      1054293.0
# 1              Show_ticket            204          1300       906167.0
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Значение выручки стоит привести к обычной форме записи из экспоненциальной с помощью `round()`.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# исправлено
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
# 1. Barplot: Топ-10 регионов по уникальным событиям
top10 = partner_stats_sorted.head(10)

plt.figure(figsize=(12, 6))
ax = sns.barplot(
    data=top10, 
    x='unique_events', 
    y='service_name', 
    palette='Blues_d'
)

plt.title('Топ-10 операторов по числу событий (осень 2024)')
plt.xlabel('Количество событий')
plt.ylabel('Оператор')

# 2. Pie chart: Доли заказов по регионам (топ-10 по заказам + прочее)
others_orders = partner_stats['unique_events'].sum() - top10['unique_events'].sum()

labels = list(top10['service_name']) + ['Прочее']
sizes = list(top10['unique_events']) + [others_orders]

plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('Set3'))
plt.title('Доли числа событий по операторам (осень 2024)')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
# 1. Barplot: Топ-10 регионов по уникальным событиям
top10 = partner_stats.sort_values('total_orders', ascending=False).head(10)

plt.figure(figsize=(12, 6))
ax = sns.barplot(
    data=top10, 
    x='total_orders', 
    y='service_name', 
    palette='Blues_d'
)

plt.title('Топ-10 операторов по числу заказов (осень 2024)')
plt.xlabel('Количество событий')
plt.ylabel('Оператор')

# 2. Pie chart: Доли заказов по регионам (топ-10 по заказам + прочее)
others_orders = partner_stats['total_orders'].sum() - top10['total_orders'].sum()

labels = list(top10['service_name']) + ['Прочее']
sizes = list(top10['total_orders']) + [others_orders]

plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('Set3'))
plt.title('Доли числа событий по операторам (осень 2024)')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
# 1. Barplot: Топ-10 регионов по уникальным событиям
top10 = partner_stats.sort_values('total_revenue', ascending=False).head(10)

plt.figure(figsize=(12, 6))
ax = sns.barplot(
    data=top10, 
    x='total_revenue', 
    y='service_name', 
    palette='Blues_d'
)

plt.title('Топ-10 операторов по числу заказов (осень 2024)')
plt.xlabel('Количество событий')
plt.ylabel('Оператор')

# 2. Pie chart: Доли заказов по регионам (топ-10 по заказам + прочее)
others_orders = partner_stats['total_revenue'].sum() - top10['total_revenue'].sum()

labels = list(top10['service_name']) + ['Прочее']
sizes = list(top10['total_revenue']) + [others_orders]

plt.figure(figsize=(8, 8))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('Set3'))
plt.title('Доли числа событий по операторам (осень 2024)')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# ###### Промежуточный вывод:
# - среди всех регионов по количеству уникальнях событий мы видим явные выдающиеся регионы, а именно: Каменевский регион (24,8%) и Североярская область (16,5%)
# - среди всех регионов по количеству заказов мы видим явные выдающиеся регионы, а именно: Каменевский регион (27,9%) и Североярская область (12,3%)
# - среди всех операторов по количеству уникальных событий мы видим явных выдающихся операторов, а именно: "Лови Билет!" (20,9%), "Билеты без проблем" (16,5%) и "Билеты в руки" (14,3%)
# - среди всех операторов по количеству заказов мы видим явных выдающихся операторов, а именно: "Лови Билет!" (15,2%), "Билеты без проблем" (19,3%) и "Билеты в руки" (15,1%)
# - среди всех операторов по количеству заказов мы видим явных выдающихся операторов, а именно: "Билеты без проблем" (15,3%) и "Облачко" (14%) и "Мой билет" (13,3%)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Регионы и площадки исследованы - тут отмечу хорошую комбинацию инструментов анализа.

# %% [markdown]
# ## 4. Статистический анализ данных

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> В этом проекте мы не можем рассчитать размер выборки, так как у нас нет базовой конверсии (в сущности, гипотеза даже не о конверсии) и ожидаемого её прироста (по той же причине).
#
# Для гипотез о средних требуемый размер выборки оценивается с помощью других инструментов.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# удален пункт с расчетом выборки
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b>
# Все библиотеки стоит импортировать в начале проекта - таким образом получатель твоего отчёта сможет узнать о проблемах с его окружением сразу перед работой с проектом, а не посреди или в конце проекта.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Длительность теста обычно рассчитывают до его проведения на этапе проектирования. Расчёт длительности теста с учётом данных о его фактических результатах - подгонка нужной длительности под фактический результат.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# удалила пункт с расчетом длительности
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ### Проверка распределения пользователей

# %%
# создаем датафреймы по каждой группе
a = df_fall[df_fall['device_type_canonical']=='mobile']
b = df_fall[df_fall['device_type_canonical']=='desktop']

# %%
# Считаем количество пользователей в каждой группе
a_count = a['user_id'].nunique()
b_count = b['user_id'].nunique()
# Считаем процентную разницу
perc_dif = abs(a_count-b_count)/a_count*100
print(f'Процентная разница в количестве пользователей групп А ({a_count}) и В ({b_count}) составляет {round(perc_dif,2)}%.')
# Out:
# Процентная разница в количестве пользователей групп А (14190) и В (4869) составляет 65.69%.

# %%
data = pd.DataFrame({'group': ['A', 'B'], 'count': [a_count, b_count]})

# Создаем круговую диаграмму с помощью seaborn и matplotlib
plt.figure(figsize=(6, 6))  # Задаем размер фигуры
plt.pie(data['count'], labels=data['group'], autopct='%1.1f%%', startangle=90, colors=sns.color_palette('pastel'),
        wedgeprops={'edgecolor': 'black'}) # Добавляем больше деталей

plt.title('Процентное соотношение между группами', fontsize=14)  
plt.ylabel('') 

plt.axis('equal')  
plt.tight_layout() 

plt.show()

# %% [markdown]
# ###### Промежуточный вывод:
# - распределение пользователей неравномерное
# - однако это не мешает проводимому эксперименту, так как мы имеем необходимый минимум в оботх выборках

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Верно отмечен дисбаланс в распределении групп.

# %% [markdown]
# ### Проверка на пересечение групп

# %%
# Находим уникальных пользователей в каждой группе
a_unique = a['user_id'].unique()
b_unique = b['user_id'].unique()
# Преобразовываем массивы в множества
a_un_set = set(a_unique)
b_un_set = set(b_unique)
# Находим пересечения
common_users = a_un_set.intersection(b_un_set)
# Выводим результат
num_common_users = len(common_users)

if num_common_users > 0:
    print(f"Внимание! Обнаружено {num_common_users} пользователей, которые есть в обеих группах (A и B).")
else:
    print("Отлично! Нет пользователей, которые одновременно состоят в обеих группах (A и B). Группы независимы.")
# Out:
# Внимание! Обнаружено 3250 пользователей, которые есть в обеих группах (A и B).

# %% [markdown]
# ###### Промежуточный вывод:
# - группы были проверены на пересечение.
# - было обнаружено 3274 пользователей, которые покупали билеты с обоих типов устройств.
# - было решено не удалять таких пользователей, а считать группы зависимыми

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Специфика работы с пользователями мобильных приложений в некоторых случаях может подразумевать использование двух девайсов сразу - к примеру, онлайн-банкинг и интернет банкинг: пользователь один и тот же, но операции может проводить на разных девайсах.

# %% [markdown]
# ### Равномерность разделения пользователей по категориям

# %%
a['event_type_main'].unique()
# Out:
# array(['театр', 'концерты', 'другое', 'спорт', 'стендап', 'ёлки',
#        'выставки', nan], dtype=object)

# %%
a_dev=a.groupby('age_limit')['user_id'].nunique()
b_dev=b.groupby('age_limit')['user_id'].nunique()
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(12,8))
ax = ax.flatten()
ax[0].pie(a_dev,
        autopct='%1.1f%%', colors=sns.color_palette('pastel'), wedgeprops={'edgecolor': 'black'})
ax[0].set_title('A')
ax[1].pie(b_dev, autopct='%1.1f%%', colors=sns.color_palette('pastel'), wedgeprops={'edgecolor': 'black'})
ax[1].set_title('B')
fig.suptitle("Доля каждой возрастной группы для групп А и В")
fig.legend(labels=['6', '0', '18','12','16'], loc='center right', title = 'Возрастная группа');

# %%
a_dev=a.groupby('event_type_main')['user_id'].nunique()
b_dev=b.groupby('event_type_main')['user_id'].nunique()
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(12,8))
ax = ax.flatten()
ax[0].pie(a_dev,
        autopct='%1.1f%%', colors=sns.color_palette('pastel'), wedgeprops={'edgecolor': 'black'})
ax[0].set_title('A')
ax[1].pie(b_dev, autopct='%1.1f%%', colors=sns.color_palette('pastel'), wedgeprops={'edgecolor': 'black'})
ax[1].set_title('B')
fig.suptitle("Доля каждого типа мероприятий для групп А и В")
fig.legend(labels=['театр', 'спорт', 'стендап', 'ёлки', 'другое', 'концерты',
       'выставки', 'не указано'], loc='center right', title = 'Возрастная группа');

# %% [markdown]
# ###### Промежуточный вывод:
# - разделение пользователей по категориям равномерно
# - после проведенной проверки можно преступить к проведению теста

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> Если делать анализ распределения пользователей по категориям, корректно сравнить все категории, а не только часть из них.

# %% [markdown]
# ###  Проверка результатов A/B-теста

# %% [markdown]
# ###### Сформулируем гипотезу для первого теста
#
# *Нулевая гипотеза:* Среднее количество заказов на одного пользователя мобильного приложения не выше среднего количества заказов на одного пользователя стационарных устройств.
#
# *Алтернативная гипотеза:* среднее количество заказов на одного пользователя мобильного приложения выше по сравнению с пользователями стационарных устройств.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> При работе с одосторонней проверкой нулевую гипотезу нужно формулировать от обратного к альтернативной: если альтернативная - `выше`, нулевая должна быть `не выше`.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# исправлено
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
#
a_avg = a.groupby('user_id')['order_id'].count()
b_avg = b.groupby('user_id')['order_id'].count()

# %%
alpha = 0.05# зафиксируйте уровень значимости

t_statistic, p_value = mannwhitneyu(a_avg, b_avg, alternative='greater') 
print(f'pvalue={p_value}, среднее количество сессий в день в группе А {a_avg.mean()}, среднее количество сессий в день в группе В {b_avg.mean()}') # Выведите полученное p-value 
# Интерпретируем p-value
alpha = 0.05  # Уровень значимости 
if p_value < alpha:
    print("P-value меньше уровня значимости. Отвергаем нулевую гипотезу о равенстве средних.  Различия в количестве сессий между группами A и B статистически значимы.")
else:
    print("P-value больше уровня значимости. Не отвергаем нулевую гипотезу о равенстве средних. Нет статистически значимых различий в количестве сессий между группами A и B.")
# Out:
# pvalue=3.459853111231813e-07, среднее количество сессий в день в группе А 9.464341085271318, среднее количество сессий в день в группе В 7.04518381597864
# P-value меньше уровня значимости. Отвергаем нулевую гипотезу о равенстве средних.  Различия в количестве сессий между группами A и B статистически значимы.

# %% [markdown]
# ###### Обоснование выбора теста Манна-Уитни
# Для анализа различий между группами был выбран U-критерий Манна-Уитни. Данный непараметрический критерий был предпочтен t-критерию Стьюдента по следующим причинам:
# 1) данные в группах не соответствуют нормальному распределению;
#
# 2) размеры сравниваемых выборок были неравны;
#
# 3) тест Манна-Уитни устойчив к выбросам.
#
# Применение критерия Манна-Уитни позволяет корректно оценить статистическую значимость наблюдаемых различий между группами без необходимости выполнения предположений о нормальности распределения данных.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Верно отмечен дисбаланс в распределении групп.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Нужно обосновать выбор теста.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# исправлено
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ###### Сформулируем гипотезу для второго теста
#
# *Нулевая гипотеза:* Среднее время между заказами пользователей мобильных приложений не выше среднего времени пользователей стационарных устройств.
#
# *Алтернативная гипотеза:* Среднее время между заказами пользователей мобильных приложений выше по сравнению с пользователями стационарных устройств.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Аналогично нужно скорректировать гипотезы.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# исправлено
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %%
#
a_mean = a['days_since_prev']
b_mean = b['days_since_prev']
a_clean = a_mean.replace([np.inf, -np.inf], np.nan).dropna()
b_clean = b_mean.replace([np.inf, -np.inf], np.nan).dropna()

# %%
statistic, p_value = mannwhitneyu(a_clean, b_clean, alternative='greater')
print(f'pvalue={p_value}, среднее количество сессий в день в группе А {a_clean.mean()}, среднее количество сессий в день в группе В {b_clean.mean()}') # Выведите полученное p-value 
# Интерпретируем p-value
alpha = 0.05  # Уровень значимости 
if p_value < alpha:
    print("P-value меньше уровня значимости. Отвергаем нулевую гипотезу о равенстве средних.  Различия в количестве сессий между группами A и B статистически значимы.")
else:
    print("P-value больше уровня значимости. Не отвергаем нулевую гипотезу о равенстве средних. Нет статистически значимых различий в количестве сессий между группами A и B.")
# Out:
# pvalue=3.2282817887795e-92, среднее количество сессий в день в группе А 3.7789280216155077, среднее количество сессий в день в группе В 3.0253756260434055
# P-value меньше уровня значимости. Отвергаем нулевую гипотезу о равенстве средних.  Различия в количестве сессий между группами A и B статистически значимы.

# %% [markdown]
# ###### Обоснование выбора теста Манна-Уитни
# Для анализа различий между группами был выбран U-критерий Манна-Уитни. Данный непараметрический критерий был предпочтен t-критерию Стьюдента по следующим причинам:
# 1) данные в группах не соответствуют нормальному распределению;
#
# 2) размеры сравниваемых выборок были неравны;
#
# 3) тест Манна-Уитни устойчив к выбросам.
#
# Применение критерия Манна-Уитни позволяет корректно оценить статистическую значимость наблюдаемых различий между группами без необходимости выполнения предположений о нормальности распределения данных.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Тестирование выполнено корректно.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Нужно обосновать выбор теста.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# исправлено
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# ###### Промежуточный вывод:
# - были проведены оба теста
# - по их результатам мы отвергли обе альтернативные гипотезы
# - теперь можно точно сказать, что среднее количество заказов на одного пользователя мобильного приложения выше по сравнению с пользователями стационарных устройств и среднее время между заказами пользователей мобильных приложений выше по сравнению с пользователями стационарных устройств

# %% [markdown]
# ## 5. Общий вывод и рекомендации

# %% [markdown]
# ### Данные
# - входные данные были не предобработаны и не очищены, поэтому пришлось провести EDA
# - в ходе предобработки были проведены следующие мероприятия: удаление явных и неявных дубликатов, проверка распределения значенийи обнаружение выбросов, преобразование типов данных в подходящие
# - добавлены новые столбцы, необходимые для анализа
# - в конце все датафреймы были объеденины в один

# %% [markdown]
# ### Исследовательский анализ
# - с каждым месяцем наблюдается увеличение количества заказов, прослеживается восходящий тренд
# - из 7 типов мероприятий только у 3 вырастает доля заказов (спорт, театр и елки). последний тип можно объяснить сезонностью и приближением новогднего периода
# - доля заказов в категории спорта и елок вырастает практически в 3,5 раза, а доля заказов в театр растет не так быстро (+26,6%)
# - остальные категории падают на 12,8-28,7%.
# - сложно оценить причины такого падения
# - однако из 7 типов мероприятий увеличение чека прослеживается только в двух (выставки на 4,8% и стендап на 5,8%)
# - падение среднего чека варьируется от 1,6% до 17,8%
# - эти события могут указывать на то, что люди осенью начинают чаще куда-либо ходить, но выбирают мероприятия более низкой стоимостью
# - видим итересную ситуацию: с увеличением количества заказов, количества уникальных пользователей и, соответсвенно, с увеличением среднего числа заказов на пользователям, происходит уменьшение среднего чека.
# - если брать недельную аналитику, то то же самое наблюдаем с увеличениеями и падениями а также: вторник самый популярный день для заказов, но в количестве уникальных пользователей вторник уступает более популрной пятнице.
# - вторник - день с наименьшим средним чеком.
# - говоря о выходных, по субботам мы имеем больше заказов, больше уникальных пользователей и выше среднего количества заказов на пользователя.
# - с средним чеком наоборот: по воскресеньям средний чек выше и в рамках выходных, и в целом на всей неделе.
# - среди всех регионов по количеству уникальнях событий мы видим явные выдающиеся регионы, а именно: Каменевский регион (24,8%) и Североярская область (16,5%)
# - среди всех регионов по количеству заказов мы видим явные выдающиеся регионы, а именно: Каменевский регион (27,9%) и Североярская область (12,3%)
# - среди всех операторов по количеству уникальных событий мы видим явных выдающихся операторов, а именно: "Лови Билет!" (20,9%), "Билеты без проблем" (16,5%) и "Билеты в руки" (14,3%)
# - среди всех операторов по количеству заказов мы видим явных выдающихся операторов, а именно: "Лови Билет!" (15,2%), "Билеты без проблем" (19,3%) и "Билеты в руки" (15,1%)
# - среди всех операторов по количеству заказов мы видим явных выдающихся операторов, а именно: "Билеты без проблем" (15,3%) и "Облачко" (14%) и "Мой билет" (13,3%)

# %% [markdown]
# ### Статистический анализ
# - была проведена подготовка для стат. анализа. а именно, проведены следующие шаги: расчет размера выборки и длительности теста, проверка распределения пользователей по выборкам, проверка на пересечение групп, равномерность разделения пользователей по категориям
# - после вышеописанных шагов была проведена проверка результатов теста
# - по результатам обоих тестов мы отвергли обе альтернативные гипотезы
# - среднее количество заказов на одного пользователя мобильного приложения выше по сравнению с пользователями стационарных устройств
# - среднее время между заказами пользователей мобильных приложений выше по сравнению с пользователями стационарных устройств

# %% [markdown]
# ### Рекомендации
# - по результатам статистических тестов, можно понять, что пользователи мобильных устройств более активны
# - для пользователей мобильной версии можно:
#
#     1) оптимизировать мобильный опыт (улучшить мобильное приложение, создать персонализацию, разработать умную систему push-уведомлений о скидках, новых мероприятиях и напоминаниях);
#
#     2) создать маркентиговые стратегии (проводить мобильный маркетинг, мобильно-ориентированные промо-акции, внедрить функцию "Купить в один клик" для авторизованных пользователей);
#
#     3) создать интеграцию с другими сервисами (Яндекс.Еда, Яндекс.Такси, т.п.)
#
#
# - для пользователей веб-версии можно:
#
#     1) стимулировать переход на мобильную версию
#
#     2) улучшить опыт на веб-версии

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Есть аналитическая записка с результатами исследования, а также интерпретацией тестов.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"></h2>
#
#
# <b>На доработку❌:</b> Обрати винмание, что аналитическая записка должна содержать ответы в том числе на вполне конкретные вопросы:
#
#     какие мероприятия наиболее востребованы, как изменилась популярность мероприятий осенью, как изменилась стоимость среднего чека. Какую информацию можно получить после изучения пользовательской активности? Существуют ли среди регионов и партнёров явные лидеры по числу заказов и выручке с продажи билетов?
#
# Сейчас записка не отвечает на них.
#
# Выводы также нужно скорректировать с учётом замечаний.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Некоторые замечания и рекомендации⚠️:</b> По результатам исследования полезно было бы дать рекомендации о том, как можно повысить конверсию.

# %% [markdown]
# <div class="alert alert-info">
# <h2> Комментарий студента <a class="tocSkip"> </h2>
#
# исправлено
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v.2 <a class="tocSkip"> </h2>
#
# <b>Все отлично!👍:</b> Учтено.

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: общий вывод по проекту.
#
# Ангелина, проект получился на довольно хорошем уровне - отличная работа над проектом, молодец!
#
# Мне нравится твой аналитический подход к выполнению проекта, ты соблюдаешь структуру работы, выполняешь её последовательно - это очень хорошо! Шаги проекта выполнены по порядку согласно плану проекта, нет смысловых и структурных ям. Важно, что не забываешь про выводы.
#
# Над проектом ещё стоит поработать - есть рекомендации по дополнению некоторых твоих шагов проекта. Такие рекомендации я отметил жёлтыми комментариями. Будет здорово, если ты учтёшь их - так проект станет структурно и содержательно более совершенным.
#
# Также в работе есть критические замечания. К этим замечаниям я оставил пояснительные комментарии красного цвета, в которых перечислил возможные варианты дальнейших действий. Уверен, ты быстро с этим управишься:)
#
# Если о том, что нужно сделать в рамках комментариев, будут возникать вопросы - оставь их, пожалуйста, в комментариях, и я отвечу на них во время следующего ревью.
#
# Также буду рад ответить на любые твои вопросы по проекту или на какие-либо другие, если они у тебя имеются - оставь их в комментариях, и я постараюсь ответить:)
#
# Жду твой проект на повторном ревью. До встречи:)

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# # Комментарий ревьюера: итоговый вывод по проекту.
#
# Ангелина, все замечания учтены - проект принят!
#
# Спасибо за хорошую работу над проектом, желаю успехов в дальнейших начинаниях:)
